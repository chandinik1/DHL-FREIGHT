# %%
import pandas as pd
from gurobipy import Model, GRB, quicksum
import time
from datetime import timedelta

# %%
# Loading the data
filename = "2025-04-09+DATEN+OR+PRAKTKUM.xlsx"
start_time = time.time()
df_terminals = pd.read_excel(filename, sheet_name="Standorte inkl. Kapa´s", nrows=40)
df_postalcodes = pd.read_excel(filename, sheet_name="PLZ inkl. Sendungsmengen", nrows=8185)
df_distance = pd.read_excel(filename, sheet_name="DISTANZEN PLZ-TERMINAL", nrows=319138)
df_postalcodes_neighbors = pd.read_excel(filename, sheet_name="ADJAZENZ (BENACHBARTE PLZ)", nrows=47837)

elapsed_time_secs = time.time() - start_time
s = timedelta(seconds=round(elapsed_time_secs))
print(s)
# Out:
# 0:00:11

# %%
print("-------------------------------------------------------")
print("Distance sheet columns:", df_distance.columns.tolist())
print("\nTerminal sheet columns:", df_terminals.columns.tolist())
print("\nPostal code sheet columns:",df_postalcodes.columns.tolist())
print("-------------------------------------------------------")
# Out:
# -------------------------------------------------------
# Distance sheet columns: ['von PLZ (TEXT)', 'von PLZ (ZAHL)', 'nach Terminalcode', 'nach Terminal', 'Distanz (km)', 'Fahrzeit (min)']
#
# Terminal sheet columns: ['Terminal code', 'Terminal name', 'Country ISO code', 'X-DOCK ADDRESS: street and building number', 'X-DOCK ADDRESS: postal code', 'X-DOCK ADDRESS: city', 'LAT', 'LON', 'Partner', 'MAX. KAPA SE (# ZUSTELLUNGEN pro Tag)']
#
# Postal code sheet columns: ['PLZ (TEXT)', 'PLZ (ZAHL)', 'Name', 'LAT', 'LON', 'ZUORDNUNG IST', 'PARTNER', 'Ø SENDUNGEN ABH pro Tag', 'Ø SENDUNGEN ZUS pro Tag']
# -------------------------------------------------------

# %%
# Preprocess Data
postal_codes = df_postalcodes["PLZ (ZAHL)"].tolist()
terminals = df_terminals["Terminal code"].tolist()

# Get capacity
capacity = df_terminals.set_index("Terminal code")["MAX. KAPA SE (# ZUSTELLUNGEN pro Tag)"].to_dict()

# Delivery volume
delivery_volume = df_postalcodes.set_index("PLZ (ZAHL)")["Ø SENDUNGEN ZUS pro Tag"].to_dict()

# Distance dictionary 
distance_dict = {(row["von PLZ (ZAHL)"], row["nach Terminalcode"]): row["Distanz (km)"] for _, row in df_distance.iterrows()}

# %%
print("Capacity of each terminals",capacity)
print("\nDelivery volume of each postal codes",delivery_volume)
print("\nPostal codes",postal_codes)
# Out:
# Capacity of each terminals {'AAH': 800, 'AQW': 425, 'BER': 1350, 'BFE': 1390, 'BRE': 1205, 'CBU': 150, 'DUI': 2100, 'EMS': 620, 'ERF': 965, 'FRA': 1940, 'GOH': 530, 'AGB': 900, 'ZEY': 1055, 'HAM': 1800, 'HAJ': 1650, 'QFB': 1355, 'CSO': 660, 'FKB': 850, 'KSF': 1380, 'KHX': 1250, 'ZNV': 1400, 'CGN': 1700, 'ZHZ': 1500, 'ZOL': 1250, 'DMP': 830, 'EUM': 1174, 'NUE': 1555, 'OKZ': 900, 'ZNJ': 1400, 'PVM': 510, 'ZPM': 2200, 'RNM': 1450, 'SCN': 320, 'SEH': 670, 'THF': 720, 'MUC': 2200, 'VIS': 450, 'QUL': 1250, 'ZQV': 1400}
#
# Delivery volume of each postal codes {1067: 13.75, 1069: 3.5, 1097: 2.75, 1099: 5.4375, 1108: 0.75, 1109: 11.875, 1127: 3.3125, 1129: 1.0625, 1139: 10.1875, 1156: 8.3125, 1157: 2.0625, 1159: 3.5625, 1169: 1.75, 1187: 3.1875, 1189: 3.75, 1217: 1.3125, 1219: 4.8125, 1237: 7.4375, 1239: 7.375, 1257: 8.875, 1259: 2.625, 1277: 7.6875, 1279: 2.375, 1307: 2.6875, 1309: 1.875, 1324: 1.0, 1326: 1.0625, 1328: 3.8125, 1445: 11.3125, 1454: 12.0625, 1458: 4.25, 1465: 0.5, 1468: 1.875, 1471: 5.3125, 1477: 1.625, 1558: 3.5625, 1561: 3.4375, 1587: 6.25, 1589: 1.1875, 1591: 2.75, 1594: 0.75, 1609: 1.25, 1612: 1.75, 1616: 0.375, 1619: 2.625, 1623: 1.0625, 1640: 5.375, 1662: 7.9375, 1665: 9.8125, 1683: 4.0625, 1689: 2.125, 1705: 9.0, 1723: 9.25, 1728: 3.5625, 1731: 1.375, 1734: 0.3125, 1737: 0.625, 1738: 0.1875, 1744: 3.625, 1762: 0.125, 1768: 0.4375, 1773: 0.75, 1774: 2.6875, 1776: 0.0, 1778: 0.1875, 1796: 13.3125, 1809: 3.375, 1814: 0.75, 1816: 0.5, 1819: 0.125, 1824: 1.1875, 1825: 0.3125, 1829: 0.0, 1833: 1.6875, 1844: 6.8125, 1847: 0.1875, 1848: 0.3125, 1855: 1.5, 1877: 5.125, 1896: 1.9375, 1900: 4.4375, 1904: 1.5625, 1906: 0.625, 1909: 0.375, 1917: 5.375, 1920: 2.375, 1936: 2.25, 1945: 1.875, 1968: 7.25, 1979: 5.5, 1983: 3.0625, 1987: 5.125, 1990: 1.0, 1993: 0.1875, 1994: 0.25, 1996: 1.4375, 1998: 0.0625, 2625: 19.375, 2627: 3.5, 2633: 0.4375, 2681: 2.25, 2689: 1.25, 2692: 1.875, 2694: 1.125, 2699: 0.875, 2708: 4.625, 2727: 0.5, 2730: 1.8125, 2733: 1.1875, 2736: 0.75, 2739: 0.4375, 2742: 0.875, 2747: 1.0, 2748: 0.4375, 2763: 12.5625, 2779: 1.125, 2782: 1.0, 2785: 0.5, 2788: 0.6875, 2791: 0.75, 2794: 0.25, 2796: 0.0625, 2797: 0.125, 2799: 0.1875, 2826: 2.5625, 2827: 1.25, 2828: 7.125, 2829: 1.6875, 2894: 0.25, 2899: 0.125, 2906: 4.9375, 2923: 2.3125, 2929: 0.6875, 2943: 8.125, 2953: 0.9375, 2956: 0.0625, 2957: 1.1875, 2959: 0.25, 2977: 11.6875, 2979: 5.5625, 2991: 1.25, 2994: 3.25, 2997: 1.25, 2999: 0.375, 3042: 6.125, 3044: 8.4375, 3046: 3.5625, 3048: 1.4375, 3050: 1.5625, 3051: 8.0625, 3052: 0.3125, 3053: 0.3125, 3054: 0.4375, 3055: 0.5625, 3058: 0.75, 3096: 1.375, 3099: 3.625, 3103: 0.4375, 3116: 0.5, 3119: 0.5625, 3130: 6.5, 3149: 3.875, 3159: 0.5625, 3172: 5.0625, 3185: 2.8125, 3197: 0.0625, 3205: 2.0, 3222: 7.8125, 3226: 2.25, 3229: 0.25, 3238: 8.75, 3246: 0.0625, 3249: 0.8125, 3253: 2.0, 4103: 11.8125, 4105: 2.0, 4107: 1.5625, 4109: 8.8125, 4129: 10.6875, 4155: 1.375, 4157: 1.4375, 4158: 8.75, 4159: 3.0625, 4177: 1.6875, 4178: 6.625, 4179: 2.875, 4205: 0.5625, 4207: 1.5, 4209: 3.375, 4229: 9.6875, 4249: 7.75, 4275: 2.5625, 4277: 3.6875, 4279: 0.8125, 4288: 3.125, 4289: 3.0, 4299: 1.25, 4315: 1.1875, 4316: 2.3125, 4317: 2.875, 4318: 0.625, 4319: 11.375, 4328: 4.25, 4329: 4.5625, 4347: 19.25, 4349: 92.5625, 4356: 94.0, 4357: 2.0625, 4416: 13.25, 4420: 10.375, 4425: 5.5, 4435: 15.0, 4442: 5.875, 4451: 2.75, 4463: 2.3125, 4509: 10.3125, 4519: 1.5, 4523: 0.9375, 4539: 1.3125, 4552: 9.5, 4564: 0.8125, 4565: 0.1875, 4567: 0.5625, 4571: 1.5625, 4575: 1.9375, 4600: 5.5625, 4603: 6.4375, 4610: 2.25, 4613: 0.125, 4617: 2.1875, 4618: 0.375, 4626: 7.625, 4639: 2.5625, 4643: 1.9375, 4651: 1.4375, 4654: 2.0625, 4668: 10.75, 4680: 1.6875, 4683: 5.0625, 4687: 0.8125, 4703: 2.25, 4720: 19.3125, 4736: 2.25, 4741: 1.8125, 4746: 1.5625, 4749: 3.3125, 4758: 11.375, 4769: 0.6875, 4774: 0.5625, 4779: 0.9375, 4808: 6.875, 4821: 1.9375, 4824: 2.125, 4827: 6.5625, 4828: 1.125, 4838: 8.0625, 4849: 2.8125, 4860: 7.25, 4861: 0.1875, 4862: 1.0, 4874: 0.9375, 4880: 0.75, 4886: 0.6875, 4889: 1.0, 4895: 1.625, 4910: 5.0, 4916: 4.0625, 4924: 1.5, 4928: 0.25, 4931: 0.25, 4932: 1.5625, 4934: 0.0625, 4936: 0.625, 4938: 0.875, 6108: 3.625, 6110: 7.5, 6112: 8.9375, 6114: 2.3125, 6116: 25.0, 6118: 6.5, 6120: 2.9375, 6122: 2.75, 6124: 0.625, 6126: 6.25, 6128: 1.1875, 6130: 1.75, 6132: 6.1875, 6179: 8.125, 6184: 12.1875, 6188: 31.75, 6193: 4.75, 6198: 5.5625, 6217: 13.5625, 6231: 4.6875, 6237: 11.0, 6242: 1.625, 6246: 1.625, 6249: 0.9375, 6255: 0.1875, 6258: 3.25, 6259: 0.125, ...
#
# Postal codes [1067, 1069, 1097, 1099, 1108, 1109, 1127, 1129, 1139, 1156, 1157, 1159, 1169, 1187, 1189, 1217, 1219, 1237, 1239, 1257, 1259, 1277, 1279, 1307, 1309, 1324, 1326, 1328, 1445, 1454, 1458, 1465, 1468, 1471, 1477, 1558, 1561, 1587, 1589, 1591, 1594, 1609, 1612, 1616, 1619, 1623, 1640, 1662, 1665, 1683, 1689, 1705, 1723, 1728, 1731, 1734, 1737, 1738, 1744, 1762, 1768, 1773, 1774, 1776, 1778, 1796, 1809, 1814, 1816, 1819, 1824, 1825, 1829, 1833, 1844, 1847, 1848, 1855, 1877, 1896, 1900, 1904, 1906, 1909, 1917, 1920, 1936, 1945, 1968, 1979, 1983, 1987, 1990, 1993, 1994, 1996, 1998, 2625, 2627, 2633, 2681, 2689, 2692, 2694, 2699, 2708, 2727, 2730, 2733, 2736, 2739, 2742, 2747, 2748, 2763, 2779, 2782, 2785, 2788, 2791, 2794, 2796, 2797, 2799, 2826, 2827, 2828, 2829, 2894, 2899, 2906, 2923, 2929, 2943, 2953, 2956, 2957, 2959, 2977, 2979, 2991, 2994, 2997, 2999, 3042, 3044, 3046, 3048, 3050, 3051, 3052, 3053, 3054, 3055, 3058, 3096, 3099, 3103, 3116, 3119, 3130, 3149, 3159, 3172, 3185, 3197, 3205, 3222, 3226, 3229, 3238, 3246, 3249, 3253, 4103, 4105, 4107, 4109, 4129, 4155, 4157, 4158, 4159, 4177, 4178, 4179, 4205, 4207, 4209, 4229, 4249, 4275, 4277, 4279, 4288, 4289, 4299, 4315, 4316, 4317, 4318, 4319, 4328, 4329, 4347, 4349, 4356, 4357, 4416, 4420, 4425, 4435, 4442, 4451, 4463, 4509, 4519, 4523, 4539, 4552, 4564, 4565, 4567, 4571, 4575, 4600, 4603, 4610, 4613, 4617, 4618, 4626, 4639, 4643, 4651, 4654, 4668, 4680, 4683, 4687, 4703, 4720, 4736, 4741, 4746, 4749, 4758, 4769, 4774, 4779, 4808, 4821, 4824, 4827, 4828, 4838, 4849, 4860, 4861, 4862, 4874, 4880, 4886, 4889, 4895, 4910, 4916, 4924, 4928, 4931, 4932, 4934, 4936, 4938, 6108, 6110, 6112, 6114, 6116, 6118, 6120, 6122, 6124, 6126, 6128, 6130, 6132, 6179, 6184, 6188, 6193, 6198, 6217, 6231, 6237, 6242, 6246, 6249, 6255, 6258, 6259, 6268, 6279, 6295, 6308, 6311, 6313, 6317, 6333, 6343, 6347, 6366, 6369, 6385, 6386, 6388, 6406, 6408, 6420, 6425, 6429, 6449, 6456, 6458, 6463, 6464, 6466, 6467, 6469, 6484, 6485, 6493, 6502, 6526, 6528, 6536, 6537, 6542, 6543, 6556, 6567, 6571, 6577, 6578, 6618, 6628, 6632, 6636, 6638, 6642, 6647, 6648, 6667, 6679, 6682, 6686, 6688, 6711, 6712, 6721, 6722, 6729, 6749, 6766, 6772, 6773, 6774, 6779, 6780, 6785, 6792, 6794, 6796, 6800, 6803, 6808, 6809, 6842, 6844, 6846, 6847, 6849, 6861, 6862, 6868, 6869, 6886, 6888, 6889, 6895, 6901, 6905, 6917, 6925, 7318, 7330, 7333, 7334, 7338, 7343, 7349, 7356, 7366, 7368, 7381, 7387, 7389, 7407, 7422, 7426, 7427, 7429, 7545, 7546, 7548, 7549, 7551, 7552, 7554, 7557, 7570, 7580, 7586, 7589, 7607, 7613, 7616, 7619, 7629, 7639, 7646, 7743, 7745, 7747, 7749, 7751, 7768, 7774, 7778, 7806, 7819, 7907, 7919, 7922, 7924, 7926, 7927, 7929, 7937, 7950, 7952, 7955, 7957, 7958, 7973, 7980, 7985, 7987, 8056, 8058, 8060, 8062, 8064, 8066, 8107, 8112, 8115, 8118, 8132, 8134, 8141, 8144, 8147, 8209, 8223, 8228, 8233, 8236, 8237, 8239, 8248, 8258, 8261, 8262, 8267, 8280, 8289, 8294, 8297, 8301, 8304, 8309, 8315, 8321, 8324, 8328, 8340, 8344, 8349, 8352, 8359, 8371, 8373, 8393, 8396, 8412, 8427, 8428, 8451, 8459, 8468, 8485, 8491, 8496, 8499, 8523, 8525, 8527, 8529, 8538, 8539, 8541, 8543, 8547, 8548, 8606, 8626, 8645, 8648, 9111, 9112, 9113, 9114, 9116, 9117, 9119, 9120, 9122, 9123, 9125, 9126, 9127, 9128, 9130, 9131, 9212, 9217, 9221, 9224, 9228, 9232, 9235, 9236, 9241, 9243, 9244, 9247, 9249, 9306, 9322, 9326, 9328, 9337, 9350, 9353, 9355, 9356, 9366, 9376, 9380, 9385, 9387, 9390, 9392, 9394, 9399, 9405, 9419, 9423, 9427, 9429, 9430, 9432, 9434, 9437, 9439, 9456, 9465, 9468, 9471, 9474, 9477, 9481, 9484, 9487, 9488, 9496, 9509, 9514, 9518, 9526, 9544, 9548, 9557, 9569, 9573, 9575, 9577, 9579, 9599, 9600, 9603, 9618, 9619, 9623, 9627, 9629, 9633, 9634, 9638, 9648, 9661, 9669, 10115, 10117, 10119, 10178, 10179, 10243, 10245, 10247, 10249, 10315, 10317, 10318, 10319, 10365, 10367, 10369, 10405, 10407, 10409, 10435, 10437, 10439, 10551, 10553, 10555, 10557, 10559, 10585, 10587, 10589, 10623, 10625, 10627, 10629, 10707, 107 ...

# %%
sample_plz_list = postal_codes

print("Processing Neighbors for selected PLZs...")

neighbors = {}

# Build neighbors dictionary for selected PLZs
for plz in sample_plz_list:
    # Find all neighbors of 'plz' in the neighbor DataFrame
    neighbor_rows = df_postalcodes_neighbors[df_postalcodes_neighbors['PLZ'] == plz]
    valid_neighbors_in_sample = [
        neighbor for neighbor in neighbor_rows['benachbarte PLZ'] if neighbor in sample_plz_list
    ]
    neighbors[plz] = valid_neighbors_in_sample

# Neighbor constraints
print("Determining neighbor status (z_i) for selected PLZs...")

has_neighbors_z = {}
for plz in sample_plz_list:
    if plz in neighbors and neighbors[plz]:
        has_neighbors_z[plz] = 1
    else:
        has_neighbors_z[plz] = 0

#print("Neighbors..",has_neighbors_z)
# Out:
# Processing Neighbors for selected PLZs...
# Determining neighbor status (z_i) for selected PLZs...

# %%
# Gurobi Model
model = Model("Capacitated Facility Location- Simpler model")

# Variables
# We are declaring assign as a Binary variable which says whether the postal code is assigned to the terminal or not
assign = model.addVars(postal_codes, terminals, vtype=GRB.BINARY)

x = model.addVars(postal_codes, terminals, vtype=GRB.BINARY)

# Objective Function: Minimize total distance assuming that cost equals distance
model.setObjective(quicksum(assign[p, t] * distance_dict.get((p, t)) for p in postal_codes for t in terminals), GRB.MINIMIZE)

# 1. Constraint- Each postal code is assigned to exactly one terminal
model.addConstrs((quicksum(assign[p, t] for t in terminals) == 1 for p in postal_codes))

# 2. Constraint- Respect Terminal capacity
model.addConstrs((quicksum(assign[p, t] * delivery_volume.get(p, 0) for p in postal_codes) <= capacity[t] for t in terminals))

# 3. Constraint- Island constraint
model.addConstrs((has_neighbors_z[i] * (quicksum(x[k, j] for k in neighbors.get(i, [])) - x[i, j]) >= 0
                  for i in postal_codes for j in terminals))

model.optimize()
print("---------",model.status)

if model.status == GRB.OPTIMAL:
    print("\nOptimal Assignment:")
    for p in postal_codes:
        for t in terminals:
            if assign[p, t].X == 1: #if the postal code is assigned to terminal: print the postal code and corresponding terminal
                print(f"Postal Code {p} assigned to Terminal {t}")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.4.0 24E263)
#
# CPU model: Apple M3 Pro
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
#
# Optimize a model with 327359 rows, 638274 columns and 2815371 nonzeros
# Model fingerprint: 0x2eba60a1
# Variable types: 0 continuous, 638274 integer (638274 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 2e+02]
#   Objective range  [1e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 3253241.3100
# Presolve removed 319289 rows and 325068 columns
# Presolve time: 0.64s
# Presolved: 8070 rows, 313206 columns, 626412 nonzeros
# Found heuristic solution: objective 3195182.5700
# Variable types: 0 continuous, 313206 integer (313206 binary)
# Performing another presolve...
# Presolve time: 0.72s
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 3.132e+05
#  Factor NZ  : 4.147e+05 (roughly 130 MB of memory)
#  Factor Ops : 2.175e+07 (less than 1 second per iteration)
#  Threads    : 9
#
# Barrier performed 0 iterations in 2.07 seconds (2.98 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.08s
#
# Solved with dual simplex
#
# Root relaxation: objective 4.164072e+05, 19 iterations, 0.45 seconds (0.29 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 416407.211    0    6 3195182.57 416407.211  87.0%     -    2s
# H    0     0                    416474.02000 416407.211  0.02%     -    2s
# H    0     0                    416456.03000 416407.211  0.01%     -    2s
# H    0     0                    416455.57000 416407.211  0.01%     -    2s
# H    0     0                    416438.96000 416407.211  0.01%     -    2s
#
# Explored 1 nodes (19 simplex iterations) in 2.45 seconds (3.11 work units)
# Thread count was 11 (of 11 available processors)
#
# Solution count 6: 416439 416456 416456 ... 3.25324e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.164389600000e+05, best bound 4.164072107096e+05, gap 0.0076%
# --------- 2
#
# Optimal Assignment:
# Postal Code 1067 assigned to Terminal KHX
# Postal Code 1069 assigned to Terminal KHX
# Postal Code 1097 assigned to Terminal KHX
# Postal Code 1099 assigned to Terminal KHX
# Postal Code 1108 assigned to Terminal KHX
# Postal Code 1109 assigned to Terminal KHX
# Postal Code 1127 assigned to Terminal KHX
# Postal Code 1129 assigned to Terminal KHX
# Postal Code 1139 assigned to Terminal KHX
# Postal Code 1156 assigned to Terminal KHX
# Postal Code 1157 assigned to Terminal KHX
# Postal Code 1159 assigned to Terminal KHX
# Postal Code 1169 assigned to Terminal KHX
# Postal Code 1187 assigned to Terminal KHX
# Postal Code 1189 assigned to Terminal KHX
# Postal Code 1217 assigned to Terminal KHX
# Postal Code 1219 assigned to Terminal KHX
# Postal Code 1237 assigned to Terminal KHX
# Postal Code 1239 assigned to Terminal KHX
# Postal Code 1257 assigned to Terminal KHX
# Postal Code 1259 assigned to Terminal KHX
# Postal Code 1277 assigned to Terminal KHX
# Postal Code 1279 assigned to Terminal KHX
# Postal Code 1307 assigned to Terminal KHX
# Postal Code 1309 assigned to Terminal KHX
# Postal Code 1324 assigned to Terminal KHX
# Postal Code 1326 assigned to Terminal KHX
# Postal Code 1328 assigned to Terminal KHX
# Postal Code 1445 assigned to Terminal KHX
# Postal Code 1454 assigned to Terminal KHX
# Postal Code 1458 assigned to Terminal KHX
# Postal Code 1465 assigned to Terminal KHX
# Postal Code 1468 assigned to Terminal KHX
# Postal Code 1471 assigned to Terminal KHX
# Postal Code 1477 assigned to Terminal KHX
# Postal Code 1558 assigned to Terminal KHX
# Postal Code 1561 assigned to Terminal KHX
# Postal Code 1587 assigned to Terminal KHX
# Postal Code 1589 assigned to Terminal KHX
# Postal Code 1591 assigned to Terminal KHX
# Postal Code 1594 assigned to Terminal KHX
# Postal Code 1609 assigned to Terminal KHX
# Postal Code 1612 assigned to Terminal KHX
# Postal Code 1616 assigned to Terminal KHX
# Postal Code 1619 assigned to Terminal KHX
# Postal Code 1623 assigned to Terminal KHX
# Postal Code 1640 assigned to Terminal KHX
# Postal Code 1662 assigned to Terminal KHX
# Postal Code 1665 assigned to Terminal KHX
# Postal Code 1683 assigned to Terminal KHX
# Postal Code 1689 assigned to Terminal KHX
# Postal Code 1705 assigned to Terminal KHX
# Postal Code 1723 assigned to Terminal KHX
# Postal Code 1728 assigned to Terminal KHX
# Postal Code 1731 assigned to Terminal KHX
# Postal Code 1734 assigned to Terminal KHX
# Postal Code 1737 assigned to Terminal KHX
# Postal Code 1738 assigned to Terminal KHX
# Postal Code 1744 assigned to Terminal KHX
# Postal Code 1762 assigned to Terminal KHX
# Postal Code 1768 assigned to Terminal KHX
# Postal Code 1773 assigned to Terminal KHX
# Postal Code 1774 assigned to Terminal KHX
# Postal Code 1776 assigned to Terminal KHX
# Postal Code 1778 assigned to Terminal KHX
# Postal Code 1796 assigned to Terminal KHX
# Postal Code 1809 assigned to Terminal KHX
# Postal Code 1814 assigned to Terminal KHX
# Postal Code 1816 assigned to Terminal KHX
# Postal Code 1819 assigned to Terminal KHX
# Postal Code 1824 assigned to Terminal KHX
# Postal Code 1825 assigned to Terminal KHX
# Postal Code 1829 assigned to Terminal KHX
# Postal Code 1833 assigned to Terminal KHX
# Postal Code 1844 assigned to Terminal KHX
# Postal Code 1847 assigned to Terminal KHX
# Postal Code 1848 assigned to Terminal KHX
# Postal Code 1855 assigned to Terminal KHX
# Postal Code 1877 assigned to Terminal KHX
# Postal Code 1896 assigned to Terminal KHX
# Postal Code 1900 assigned to Terminal KHX
# Postal Code 1904 assigned to Terminal KHX
# Postal Code 1906 assigned to Terminal KHX
# Postal Code 1909 assigned to Terminal KHX
# Postal Code 1917 assigned to Terminal KHX
# Postal Code 1920 assigned to Terminal KHX
# Postal Code 1936 assigned to Terminal KHX
# Postal Code 1945 assigned to Terminal CBU
# Postal Code 1968 assigned to Terminal KHX
# Postal Code 1979 assigned to Terminal KHX
# Postal Code 1983 assigned to Terminal CBU
# Postal Code 1987 assigned to Terminal KHX
# Postal Code 1990 assigned to Terminal KHX
# Postal Code 1993 assigned to Terminal CBU
# Postal Code 1994 assigned to Terminal CBU
# Postal Code 1996 assigned to Terminal CBU
# Postal Code 1998 assigned to Terminal CBU
# Postal Code 2625 assigned to Terminal KHX
# Postal Code 2627 assigned to Terminal KHX
# Postal Code 2633 assigned to Terminal KHX
# Postal Code 2681 assigned to Terminal KHX
# Postal Code 2689 assigned to Terminal KHX
# Postal Code 2692 assigned to Terminal KHX
# Postal Code 2694 assigned to Terminal CBU
# Postal Code 2699 assigned to Terminal CBU
# Postal Code 2708 assigned to Terminal KHX
# Postal Code 2727 assigned to Terminal KHX
# Postal Code 2730 assigned to Terminal KHX
# Postal Code 2733 assigned to Terminal KHX
# Postal Code 2736 assigned to Terminal KHX
# Postal Code 2739 assigned to Terminal KHX
# Postal Code 2742 assigned to Terminal KHX
# Postal Code 2747 assigned to Terminal KHX
# Postal Code 2748 assigned to Terminal KHX
# Postal Code 2763 assigned to Terminal KHX
# Postal Code 2779 assigned to Terminal KHX
# Postal Code 2782 assigned to Terminal KHX
# Postal Code 2785 assigned to Terminal KHX
# Postal Code 2788 assigned to Terminal KHX
# Postal Code 2791 assigned to Terminal KHX
# Postal Code 2794 assigned to Terminal KHX
# Postal Code 2796 assigned to Terminal CBU
# Postal Code 2797 assigned to Terminal KHX
# Postal Code 2799 assigned to Terminal CBU
# Postal Code 2826 assigned to Terminal CBU
# Postal Code 2827 assigned to Terminal CBU
# Postal Code 2828 assigned to Terminal KHX
# Postal Code 2829 assigned to Terminal CBU
# Postal Code 2894 assigned to Terminal CBU
# Postal Code 2899 assigned to Terminal CBU
# Postal Code 2906 assigned to Terminal CBU
# Postal Code 2923 assigned to Terminal CBU
# Postal Code 2929 assigned to Terminal CBU
# Postal Code 2943 assigned to Terminal CBU
# Postal Code 2953 assigned to Terminal CBU
# Postal Code 2956 assigned to Terminal CBU
# Postal Code 2957 assigned to Terminal CBU
# Postal Code 2959 assigned to Terminal CBU
# Postal Code 2977 assigned to Terminal KHX
# Postal Code 2979 assigned to Terminal CBU
# Postal Code 2991 assigned to Terminal CBU
# Postal Code 2994 assigned to Terminal KHX
# Postal Code 2997 assigned to Terminal CBU
# Postal Code 2999 assigned to Terminal CBU
# Postal Code 3042 assigned to Terminal CBU
# Postal Code 3044 assigned to Terminal CBU
# Postal Code 3046 assigned to Terminal CBU
# Postal Code 3048 assigned to Terminal CBU
# Postal Code 3050 assigned to Terminal CBU
# Postal Code 3051 assigned to Terminal CBU
# Postal Code 3052 assigned to Terminal CBU
# Postal Code 3053 assigned to Terminal CBU
# Postal Code 3054 assigned to Terminal CBU
# Postal Code 3055 assigned to Terminal CBU
# Postal Code 3058 assigned to Terminal CBU
# Postal Code 3096 assigned to Terminal CBU
# Postal Code 3099 assigned to Terminal CBU
# Postal Code 3103 assigned to Terminal CBU
# Postal Code 3116 assigned to Terminal CBU
# Postal Code 3119 assigned to Terminal CBU
# Postal Code 3130 assigned to Terminal CBU
# Postal Code 3149 assigned to Terminal CBU
# Postal Code 3159 assigned to Terminal CBU
# Postal Code 3172 assigned to Terminal CBU
# Postal Code 3185 assigned to Terminal CBU
# Postal Code 3197 assigned to Terminal CBU
# Postal Code 3205 assigned to Terminal CBU
# Postal Code 3222 assigned to Terminal CBU
# Postal Code 3226 assigned to Terminal CBU
# Postal Code 3229 assigned to Terminal CBU
# Postal Code 3238 assigned to Terminal KHX
# Postal Code 3246 assigned to Terminal CBU
# Postal Code 3249 assigned to Terminal CBU
# Postal Code 3253 assigned to Terminal KHX
# Postal Code 4103 assigned to Terminal ZHZ
# Postal Code 4105 assigned to Terminal ZHZ
# Postal Code 4107 assigned to Terminal ZHZ
# Postal Code 4109 assigned to Terminal ZHZ
# Postal Code 4129 assigned to Terminal ZHZ
# Postal Code 4155 assigned to Terminal ZHZ
# Postal Code 4157 assigned to Terminal ZHZ
# Postal Code 4158 assigned to Terminal ZHZ
# Postal Code 4159 assigned to Terminal ZHZ
# Postal Code 4177 assigned to Terminal ZHZ
# Postal Code 4178 assigned to Terminal ZHZ
# Postal Code 4179 assigned to Terminal ZHZ
# Postal Code 4205 assigned to Terminal ZHZ
# Postal Code 4207 assigned to Terminal ZHZ
# Postal Code 4209 assigned to Terminal ZHZ
# Postal Code 4229 assigned to Terminal ZHZ
# Postal Code 4249 assigned to Terminal ZHZ
# Postal Code 4275 assigned to Terminal ZHZ
# Postal Code 4277 assigned to Terminal ZHZ
# Postal Code 4279 assigned to Terminal ZHZ
# Postal Code 4288 assigned to Terminal ZHZ
# Postal Code 4289 assigned to Terminal ZHZ
# Postal Code 4299 assigned to Terminal ZHZ
# Postal Code 4315 assigned to Terminal ZHZ
# Postal Code 4316 assigned to Terminal ZHZ
# Postal Code 4317 assigned to Terminal ZHZ
# Postal Code 4318 assigned to Terminal ZHZ
# Postal Code 4319 assigned to Terminal ZHZ
# Postal Code 4328 assigned to Terminal ZHZ
# Postal Code 4329 assigned to Terminal ZHZ
# Postal Code 4347 assigned to Terminal ZHZ
# Postal Code 4349 assigned to Terminal ZHZ
# Postal Code 4356 assigned to Terminal ZHZ
# Postal Code 4357 assigned to Terminal ZHZ
# Postal Code 4416 assigned to Terminal ZHZ
# Postal Code 4420 assigned to Terminal ZHZ
# Postal Code 4425 assigned to Terminal ZHZ
# Postal Code 4435 assigned to Terminal ZHZ
# Postal Code 4442 assigned to Terminal ZHZ
# Postal Code 4451 assigned to Terminal ZHZ
# Postal Code 4463 assigned to Terminal ZHZ
# Postal Code 4509 assigned to Terminal ZHZ
# Postal Code 4519 assigned to Terminal ZHZ
# Postal Code 4523 assigned to Terminal ZHZ
# Postal Code 4539 assigned to Terminal ZHZ
# Postal Code 4552 assigned to Terminal ZHZ
# Postal Code 4564 assigned to Terminal ZHZ
# Postal Code 4565 assigned to Terminal ZHZ
# Postal Code 4567 assigned to Terminal ZHZ
# Postal Code 4571 assigned to Terminal ZHZ
# Postal Code 4575 assigned to Terminal ZHZ
# Postal Code 4600 assigned to Terminal ZHZ
# Postal Code 4603 assigned to Terminal ZHZ
# Postal Code 4610 assigned to Terminal ZHZ
# Postal Code 4613 assigned to Terminal ZHZ
# Postal Code 4617 assigned to Terminal ZHZ
# Postal Code 4618 assigned to Terminal KHX
# Postal Code 4626 assigned to Terminal ERF
# Postal Code 4639 assigned to Terminal OKZ
# Postal Code 4643 assigned to Terminal KHX
# Postal Code 4651 assigned to Terminal KHX
# Postal Code 4654 assigned to Terminal ZHZ
# Postal Code 4668 assigned to Terminal ZHZ
# Postal Code 4680 assigned to Terminal KHX
# Postal Code 4683 assigned to Terminal ZHZ
# Postal Code 4687 assigned to Terminal ZHZ
# Postal Code 4703 assigned to Terminal KHX
# Postal Code 4720 assigned to Terminal KHX
# Postal Code 4736 assigned to Terminal KHX
# Postal Code 4741 assigned to Terminal KHX
# Postal Code 4746 assigned to Terminal KHX
# Postal Code 4749 assigned to Terminal KHX
# Postal Code 4758 assigned to Terminal KHX
# Postal Code 4769 assigned to Terminal KHX
# Postal Code 4774 assigned to Terminal KHX
# Postal Code 4779 assigned to Terminal KHX
# Postal Code 4808 assigned to Terminal ZHZ
# Postal Code 4821 assigned to Terminal ZHZ
# Postal Code 4824 assigned to Terminal ZHZ
# Postal Code 4827 assigned to Terminal ZHZ
# Postal Code 4828 assigned to Terminal ZHZ
# Postal Code 4838 assigned to Terminal ZHZ
# Postal Code 4849 assigned to Terminal ZHZ
# Postal Code 4860 assigned to Terminal ZHZ
# Postal Code 4861 assigned to Terminal ZHZ
# Postal Code 4862 assigned to Terminal ZHZ
# Postal Code 4874 assigned to Terminal KHX
# Postal Code 4880 assigned to Terminal ZHZ
# Postal Code 4886 assigned to Terminal ZHZ
# Postal Code 4889 assigned to Terminal KHX
# Postal Code 4895 assigned to Terminal KHX
# Postal Code 4910 assigned to Terminal KHX
# Postal Code 4916 assigned to Terminal KHX
# Postal Code 4924 assigned to Terminal KHX
# Postal Code 4928 assigned to Terminal KHX
# Postal Code 4931 assigned to Terminal KHX
# Postal Code 4932 assigned to Terminal KHX
# Postal Code 4934 assigned to Terminal KHX
# Postal Code 4936 assigned to Terminal CBU
# Postal Code 4938 assigned to Terminal KHX
# Postal Code 6108 assigned to Terminal ZHZ
# Postal Code 6110 assigned to Terminal ZHZ
# Postal Code 6112 assigned to Terminal ZHZ
# Postal Code 6114 assigned to Terminal ZHZ
# Postal Code 6116 assigned to Terminal ZHZ
# Postal Code 6118 assigned to Terminal ZHZ
# Postal Code 6120 assigned to Terminal ZHZ
# Postal Code 6122 assigned to Terminal ZHZ
# Postal Code 6124 assigned to Terminal ZHZ
# Postal Code 6126 assigned to Terminal ZHZ
# Postal Code 6128 assigned to Terminal ZHZ
# Postal Code 6130 assigned to Terminal ZHZ
# Postal Code 6132 assigned to Terminal ZHZ
# Postal Code 6179 assigned to Terminal ZHZ
# Postal Code 6184 assigned to Terminal ZHZ
# Postal Code 6188 assigned to Terminal ZHZ
# Postal Code 6193 assigned to Terminal ZHZ
# Postal Code 6198 assigned to Terminal ZHZ
# Postal Code 6217 assigned to Terminal ZHZ
# Postal Code 6231 assigned to Terminal ZHZ
# Postal Code 6237 assigned to Terminal ZHZ
# Postal Code 6242 assigned to Terminal ZHZ
# Postal Code 6246 assigned to Terminal ZHZ
# Postal Code 6249 assigned to Terminal ZHZ
# Postal Code 6255 assigned to Terminal ZHZ
# Postal Code 6258 assigned to Terminal ZHZ
# Postal Code 6259 assigned to Terminal ZHZ
# Postal Code 6268 assigned to Terminal ZHZ
# Postal Code 6279 assigned to Terminal ZHZ
# Postal Code 6295 assigned to Terminal ZHZ
# Postal Code 6308 assigned to Terminal ZHZ
# Postal Code 6311 assigned to Terminal ZHZ
# Postal Code 6313 assigned to Terminal ZHZ
# Postal Code 6317 assigned to Terminal ZHZ
# Postal Code 6333 assigned to Terminal ZHZ
# Postal Code 6343 assigned to Terminal ZHZ
# Postal Code 6347 assigned to Terminal ZHZ
# Postal Code 6366 assigned to Terminal ZHZ
# Postal Code 6369 assigned to Terminal ZHZ
# Postal Code 6385 assigned to Terminal ZHZ
# Postal Code 6386 assigned to Terminal ZHZ
# Postal Code 6388 assigned to Terminal ZHZ
# Postal Code 6406 assigned to Terminal ZHZ
# Postal Code 6408 assigned to Terminal CSO
# Postal Code 6420 assigned to Terminal ZHZ
# Postal Code 6425 assigned to Terminal ZHZ
# Postal Code 6429 assigned to Terminal CSO
# Postal Code 6449 assigned to Terminal CSO
# Postal Code 6456 assigned to Terminal ZHZ
# Postal Code 6458 assigned to Terminal CSO
# Postal Code 6463 assigned to Terminal CSO
# Postal Code 6464 assigned to Terminal CSO
# Postal Code 6466 assigned to Terminal CSO
# Postal Code 6467 assigned to Terminal CSO
# Postal Code 6469 assigned to Terminal CSO
# Postal Code 6484 assigned to Terminal CSO
# Postal Code 6485 assigned to Terminal CSO
# Postal Code 6493 assigned to Terminal CSO
# Postal Code 6502 assigned to Terminal CSO
# Postal Code 6526 assigned to Terminal ZHZ
# Postal Code 6528 assigned to Terminal ERF
# Postal Code 6536 assigned to Terminal ERF
# Postal Code 6537 assigned to Terminal ERF
# Postal Code 6542 assigned to Terminal ERF
# Postal Code 6543 assigned to Terminal ZHZ
# Postal Code 6556 assigned to Terminal ERF
# Postal Code 6567 assigned to Terminal ERF
# Postal Code 6571 assigned to Terminal ERF
# Postal Code 6577 assigned to Terminal ERF
# Postal Code 6578 assigned to Terminal ERF
# Postal Code 6618 assigned to Terminal ERF
# Postal Code 6628 assigned to Terminal ERF
# Postal Code 6632 assigned to Terminal ZHZ
# Postal Code 6636 assigned to Terminal ZHZ
# Postal Code 6638 assigned to Terminal ZHZ
# Postal Code 6642 assigned to Terminal ZHZ
# Postal Code 6647 assigned to Terminal ERF
# Postal Code 6648 assigned to Terminal ERF
# Postal Code 6667 assigned to Terminal ZHZ
# Postal Code 6679 assigned to Terminal ZHZ
# Postal Code 6682 assigned to Terminal ZHZ
# Postal Code 6686 assigned to Terminal ZHZ
# Postal Code 6688 assigned to Terminal ZHZ
# Postal Code 6711 assigned to Terminal ZHZ
# Postal Code 6712 assigned to Terminal ZHZ
# Postal Code 6721 assigned to Terminal ZHZ
# Postal Code 6722 assigned to Terminal ZHZ
# Postal Code 6729 assigned to Terminal ZHZ
# Postal Code 6749 assigned to Terminal ZHZ
# Postal Code 6766 assigned to Terminal ZHZ
# Postal Code 6772 assigned to Terminal ZHZ
# Postal Code 6773 assigned to Terminal ZHZ
# Postal Code 6774 assigned to Terminal ZHZ
# Postal Code 6779 assigned to Terminal ZHZ
# Postal Code 6780 assigned to Terminal ZHZ
# Postal Code 6785 assigned to Terminal ZHZ
# Postal Code 6792 assigned to Terminal ZHZ
# Postal Code 6794 assigned to Terminal ZHZ
# Postal Code 6796 assigned to Terminal ZHZ
# Postal Code 6800 assigned to Terminal ZHZ
# Postal Code 6803 assigned to Terminal ZHZ
# Postal Code 6808 assigned to Terminal ZHZ
# Postal Code 6809 assigned to Terminal ZHZ
# Postal Code 6842 assigned to Terminal ZHZ
# Postal Code 6844 assigned to Terminal ZHZ
# Postal Code 6846 assigned to Terminal ZHZ
# Postal Code 6847 assigned to Terminal ZHZ
# Postal Code 6849 assigned to Terminal ZHZ
# Postal Code 6861 assigned to Terminal ZHZ
# Postal Code 6862 assigned to Terminal ZHZ
# Postal Code 6868 assigned to Terminal ZHZ
# Postal Code 6869 assigned to Terminal ZHZ
# Postal Code 6886 assigned to Terminal ZHZ
# Postal Code 6888 assigned to Terminal ZHZ
# Postal Code 6889 assigned to Terminal ZHZ
# Postal Code 6895 assigned to Terminal ZHZ
# Postal Code 6901 assigned to Terminal ZHZ
# Postal Code 6905 assigned to Terminal ZHZ
# Postal Code 6917 assigned to Terminal ZHZ
# Postal Code 6925 assigned to Terminal ZHZ
# Postal Code 7318 assigned to Terminal ERF
# Postal Code 7330 assigned to Terminal OKZ
# Postal Code 7333 assigned to Terminal ERF
# Postal Code 7334 assigned to Terminal ERF
# Postal Code 7338 assigned to Terminal OKZ
# Postal Code 7343 assigned to Terminal OKZ
# Postal Code 7349 assigned to Terminal OKZ
# Postal Code 7356 assigned to Terminal OKZ
# Postal Code 7366 assigned to Terminal OKZ
# Postal Code 7368 assigned to Terminal OKZ
# Postal Code 7381 assigned to Terminal ERF
# Postal Code 7387 assigned to Terminal ERF
# Postal Code 7389 assigned to Terminal OKZ
# Postal Code 7407 assigned to Terminal ERF
# Postal Code 7422 assigned to Terminal ERF
# Postal Code 7426 assigned to Terminal ERF
# Postal Code 7427 assigned to Terminal ERF
# Postal Code 7429 assigned to Terminal ERF
# Postal Code 7545 assigned to Terminal ERF
# Postal Code 7546 assigned to Terminal ERF
# Postal Code 7548 assigned to Terminal ERF
# Postal Code 7549 assigned to Terminal ERF
# Postal Code 7551 assigned to Terminal ERF
# Postal Code 7552 assigned to Terminal ERF
# Postal Code 7554 assigned to Terminal ERF
# Postal Code 7557 assigned to Terminal OKZ
# Postal Code 7570 assigned to Terminal OKZ
# Postal Code 7580 assigned to Terminal ERF
# Postal Code 7586 assigned to Terminal ERF
# Postal Code 7589 assigned to Terminal ERF
# Postal Code 7607 assigned to Terminal ERF
# Postal Code 7613 assigned to Terminal ERF
# Postal Code 7616 assigned to Terminal ERF
# Postal Code 7619 assigned to Terminal ZHZ
# Postal Code 7629 assigned to Terminal ERF
# Postal Code 7639 assigned to Terminal ERF
# Postal Code 7646 assigned to Terminal ERF
# Postal Code 7743 assigned to Terminal ERF
# Postal Code 7745 assigned to Terminal ERF
# Postal Code 7747 assigned to Terminal ERF
# Postal Code 7749 assigned to Terminal ERF
# Postal Code 7751 assigned to Terminal ERF
# Postal Code 7768 assigned to Terminal ERF
# Postal Code 7774 assigned to Terminal ERF
# Postal Code 7778 assigned to Terminal ERF
# Postal Code 7806 assigned to Terminal OKZ
# Postal Code 7819 assigned to Terminal OKZ
# Postal Code 7907 assigned to Terminal OKZ
# Postal Code 7919 assigned to Terminal OKZ
# Postal Code 7922 assigned to Terminal OKZ
# Postal Code 7924 assigned to Terminal OKZ
# Postal Code 7926 assigned to Terminal OKZ
# Postal Code 7927 assigned to Terminal OKZ
# Postal Code 7929 assigned to Terminal OKZ
# Postal Code 7937 assigned to Terminal OKZ
# Postal Code 7950 assigned to Terminal OKZ
# Postal Code 7952 assigned to Terminal OKZ
# Postal Code 7955 assigned to Terminal OKZ
# Postal Code 7957 assigned to Terminal OKZ
# Postal Code 7958 assigned to Terminal OKZ
# Postal Code 7973 assigned to Terminal OKZ
# Postal Code 7980 assigned to Terminal OKZ
# Postal Code 7985 assigned to Terminal OKZ
# Postal Code 7987 assigned to Terminal OKZ
# Postal Code 8056 assigned to Terminal OKZ
# Postal Code 8058 assigned to Terminal OKZ
# Postal Code 8060 assigned to Terminal OKZ
# Postal Code 8062 assigned to Terminal OKZ
# Postal Code 8064 assigned to Terminal OKZ
# Postal Code 8066 assigned to Terminal OKZ
# Postal Code 8107 assigned to Terminal OKZ
# Postal Code 8112 assigned to Terminal OKZ
# Postal Code 8115 assigned to Terminal OKZ
# Postal Code 8118 assigned to Terminal OKZ
# Postal Code 8132 assigned to Terminal OKZ
# Postal Code 8134 assigned to Terminal OKZ
# Postal Code 8141 assigned to Terminal OKZ
# Postal Code 8144 assigned to Terminal OKZ
# Postal Code 8147 assigned to Terminal OKZ
# Postal Code 8209 assigned to Terminal OKZ
# Postal Code 8223 assigned to Terminal OKZ
# Postal Code 8228 assigned to Terminal OKZ
# Postal Code 8233 assigned to Terminal OKZ
# Postal Code 8236 assigned to Terminal OKZ
# Postal Code 8237 assigned to Terminal OKZ
# Postal Code 8239 assigned to Terminal OKZ
# Postal Code 8248 assigned to Terminal OKZ
# Postal Code 8258 assigned to Terminal OKZ
# Postal Code 8261 assigned to Terminal OKZ
# Postal Code 8262 assigned to Terminal OKZ
# Postal Code 8267 assigned to Terminal OKZ
# Postal Code 8280 assigned to Terminal OKZ
# Postal Code 8289 assigned to Terminal OKZ
# Postal Code 8294 assigned to Terminal KHX
# Postal Code 8297 assigned to Terminal KHX
# Postal Code 8301 assigned to Terminal OKZ
# Postal Code 8304 assigned to Terminal OKZ
# Postal Code 8309 assigned to Terminal OKZ
# Postal Code 8315 assigned to Terminal OKZ
# Postal Code 8321 assigned to Terminal OKZ
# Postal Code 8324 assigned to Terminal OKZ
# Postal Code 8328 assigned to Terminal OKZ
# Postal Code 8340 assigned to Terminal OKZ
# Postal Code 8344 assigned to Terminal OKZ
# Postal Code 8349 assigned to Terminal OKZ
# Postal Code 8352 assigned to Terminal OKZ
# Postal Code 8359 assigned to Terminal OKZ
# Postal Code 8371 assigned to Terminal OKZ
# Postal Code 8373 assigned to Terminal KHX
# Postal Code 8393 assigned to Terminal KHX
# Postal Code 8396 assigned to Terminal KHX
# Postal Code 8412 assigned to Terminal OKZ
# Postal Code 8427 assigned to Terminal OKZ
# Postal Code 8428 assigned to Terminal OKZ
# Postal Code 8451 assigned to Terminal OKZ
# Postal Code 8459 assigned to Terminal OKZ
# Postal Code 8468 assigned to Terminal OKZ
# Postal Code 8485 assigned to Terminal OKZ
# Postal Code 8491 assigned to Terminal OKZ
# Postal Code 8496 assigned to Terminal OKZ
# Postal Code 8499 assigned to Terminal OKZ
# Postal Code 8523 assigned to Terminal OKZ
# Postal Code 8525 assigned to Terminal OKZ
# Postal Code 8527 assigned to Terminal OKZ
# Postal Code 8529 assigned to Terminal OKZ
# Postal Code 8538 assigned to Terminal OKZ
# Postal Code 8539 assigned to Terminal OKZ
# Postal Code 8541 assigned to Terminal OKZ
# Postal Code 8543 assigned to Terminal OKZ
# Postal Code 8547 assigned to Terminal OKZ
# Postal Code 8548 assigned to Terminal OKZ
# Postal Code 8606 assigned to Terminal OKZ
# Postal Code 8626 assigned to Terminal OKZ
# Postal Code 8645 assigned to Terminal OKZ
# Postal Code 8648 assigned to Terminal OKZ
# Postal Code 9111 assigned to Terminal KHX
# Postal Code 9112 assigned to Terminal KHX
# Postal Code 9113 assigned to Terminal KHX
# Postal Code 9114 assigned to Terminal KHX
# Postal Code 9116 assigned to Terminal KHX
# Postal Code 9117 assigned to Terminal KHX
# Postal Code 9119 assigned to Terminal KHX
# Postal Code 9120 assigned to Terminal KHX
# Postal Code 9122 assigned to Terminal KHX
# Postal Code 9123 assigned to Terminal KHX
# Postal Code 9125 assigned to Terminal KHX
# Postal Code 9126 assigned to Terminal KHX
# Postal Code 9127 assigned to Terminal KHX
# Postal Code 9128 assigned to Terminal KHX
# Postal Code 9130 assigned to Terminal KHX
# Postal Code 9131 assigned to Terminal KHX
# Postal Code 9212 assigned to Terminal KHX
# Postal Code 9217 assigned to Terminal KHX
# Postal Code 9221 assigned to Terminal KHX
# Postal Code 9224 assigned to Terminal KHX
# Postal Code 9228 assigned to Terminal KHX
# Postal Code 9232 assigned to Terminal KHX
# Postal Code 9235 assigned to Terminal KHX
# Postal Code 9236 assigned to Terminal KHX
# Postal Code 9241 assigned to Terminal KHX
# Postal Code 9243 assigned to Terminal KHX
# Postal Code 9244 assigned to Terminal KHX
# Postal Code 9247 assigned to Terminal KHX
# Postal Code 9249 assigned to Terminal KHX
# Postal Code 9306 assigned to Terminal KHX
# Postal Code 9322 assigned to Terminal KHX
# Postal Code 9326 assigned to Terminal KHX
# Postal Code 9328 assigned to Terminal KHX
# Postal Code 9337 assigned to Terminal KHX
# Postal Code 9350 assigned to Terminal KHX
# Postal Code 9353 assigned to Terminal KHX
# Postal Code 9355 assigned to Terminal KHX
# Postal Code 9356 assigned to Terminal KHX
# Postal Code 9366 assigned to Terminal KHX
# Postal Code 9376 assigned to Terminal KHX
# Postal Code 9380 assigned to Terminal KHX
# Postal Code 9385 assigned to Terminal KHX
# Postal Code 9387 assigned to Terminal KHX
# Postal Code 9390 assigned to Terminal KHX
# Postal Code 9392 assigned to Terminal KHX
# Postal Code 9394 assigned to Terminal KHX
# Postal Code 9399 assigned to Terminal KHX
# Postal Code 9405 assigned to Terminal KHX
# Postal Code 9419 assigned to Terminal KHX
# Postal Code 9423 assigned to Terminal KHX
# Postal Code 9427 assigned to Terminal KHX
# Postal Code 9429 assigned to Terminal KHX
# Postal Code 9430 assigned to Terminal KHX
# Postal Code 9432 assigned to Terminal KHX
# Postal Code 9434 assigned to Terminal KHX
# Postal Code 9437 assigned to Terminal KHX
# Postal Code 9439 assigned to Terminal KHX
# Postal Code 9456 assigned to Terminal KHX
# Postal Code 9465 assigned to Terminal KHX
# Postal Code 9468 assigned to Terminal KHX
# Postal Code 9471 assigned to Terminal KHX
# Postal Code 9474 assigned to Terminal KHX
# Postal Code 9477 assigned to Terminal KHX
# Postal Code 9481 assigned to Terminal KHX
# Postal Code 9484 assigned to Terminal KHX
# Postal Code 9487 assigned to Terminal KHX
# Postal Code 9488 assigned to Terminal KHX
# Postal Code 9496 assigned to Terminal KHX
# Postal Code 9509 assigned to Terminal KHX
# Postal Code 9514 assigned to Terminal KHX
# Postal Code 9518 assigned to Terminal KHX
# Postal Code 9526 assigned to Terminal KHX
# Postal Code 9544 assigned to Terminal KHX
# Postal Code 9548 assigned to Terminal KHX
# Postal Code 9557 assigned to Terminal KHX
# Postal Code 9569 assigned to Terminal KHX
# Postal Code 9573 assigned to Terminal KHX
# Postal Code 9575 assigned to Terminal KHX
# Postal Code 9577 assigned to Terminal KHX
# Postal Code 9579 assigned to Terminal KHX
# Postal Code 9599 assigned to Terminal KHX
# Postal Code 9600 assigned to Terminal KHX
# Postal Code 9603 assigned to Terminal KHX
# Postal Code 9618 assigned to Terminal KHX
# Postal Code 9619 assigned to Terminal KHX
# Postal Code 9623 assigned to Terminal KHX
# Postal Code 9627 assigned to Terminal KHX
# Postal Code 9629 assigned to Terminal KHX
# Postal Code 9633 assigned to Terminal KHX
# Postal Code 9634 assigned to Terminal KHX
# Postal Code 9638 assigned to Terminal KHX
# Postal Code 9648 assigned to Terminal KHX
# Postal Code 9661 assigned to Terminal KHX
# Postal Code 9669 assigned to Terminal KHX
# Postal Code 10115 assigned to Terminal THF
# Postal Code 10117 assigned to Terminal BER
# Postal Code 10119 assigned to Terminal THF
# Postal Code 10178 assigned to Terminal THF
# Postal Code 10179 assigned to Terminal THF
# Postal Code 10243 assigned to Terminal THF
# Postal Code 10245 assigned to Terminal THF
# Postal Code 10247 assigned to Terminal THF
# Postal Code 10249 assigned to Terminal THF
# Postal Code 10315 assigned to Terminal THF
# Postal Code 10317 assigned to Terminal THF
# Postal Code 10318 assigned to Terminal THF
# Postal Code 10319 assigned to Terminal THF
# Postal Code 10365 assigned to Terminal BER
# Postal Code 10367 assigned to Terminal THF
# Postal Code 10369 assigned to Terminal THF
# Postal Code 10405 assigned to Terminal THF
# Postal Code 10407 assigned to Terminal THF
# Postal Code 10409 assigned to Terminal THF
# Postal Code 10435 assigned to Terminal THF
# Postal Code 10437 assigned to Terminal THF
# Postal Code 10439 assigned to Terminal THF
# Postal Code 10551 assigned to Terminal THF
# Postal Code 10553 assigned to Terminal THF
# Postal Code 10555 assigned to Terminal THF
# Postal Code 10557 assigned to Terminal THF
# Postal Code 10559 assigned to Terminal THF
# Postal Code 10585 assigned to Terminal THF
# Postal Code 10587 assigned to Terminal THF
# Postal Code 10589 assigned to Terminal BER
# Postal Code 10623 assigned to Terminal THF
# Postal Code 10625 assigned to Terminal THF
# Postal Code 10627 assigned to Terminal THF
# Postal Code 10629 assigned to Terminal THF
# Postal Code 10707 assigned to Terminal THF
# Postal Code 10709 assigned to Terminal THF
# Postal Code 10711 assigned to Terminal THF
# Postal Code 10713 assigned to Terminal THF
# Postal Code 10715 assigned to Terminal THF
# Postal Code 10717 assigned to Terminal THF
# Postal Code 10719 assigned to Terminal THF
# Postal Code 10777 assigned to Terminal THF
# Postal Code 10779 assigned to Terminal THF
# Postal Code 10781 assigned to Terminal THF
# Postal Code 10783 assigned to Terminal THF
# Postal Code 10785 assigned to Terminal THF
# Postal Code 10787 assigned to Terminal THF
# Postal Code 10789 assigned to Terminal THF
# Postal Code 10823 assigned to Terminal THF
# Postal Code 10825 assigned to Terminal THF
# Postal Code 10827 assigned to Terminal THF
# Postal Code 10829 assigned to Terminal THF
# Postal Code 10961 assigned to Terminal THF
# Postal Code 10963 assigned to Terminal THF
# Postal Code 10965 assigned to Terminal THF
# Postal Code 10967 assigned to Terminal THF
# Postal Code 10969 assigned to Terminal THF
# Postal Code 10997 assigned to Terminal THF
# Postal Code 10999 assigned to Terminal THF
# Postal Code 12043 assigned to Terminal THF
# Postal Code 12045 assigned to Terminal THF
# Postal Code 12047 assigned to Terminal THF
# Postal Code 12049 assigned to Terminal THF
# Postal Code 12051 assigned to Terminal THF
# Postal Code 12053 assigned to Terminal THF
# Postal Code 12055 assigned to Terminal THF
# Postal Code 12057 assigned to Terminal THF
# Postal Code 12059 assigned to Terminal THF
# Postal Code 12099 assigned to Terminal THF
# Postal Code 12101 assigned to Terminal THF
# Postal Code 12103 assigned to Terminal THF
# Postal Code 12105 assigned to Terminal THF
# Postal Code 12107 assigned to Terminal THF
# Postal Code 12109 assigned to Terminal THF
# Postal Code 12157 assigned to Terminal THF
# Postal Code 12159 assigned to Terminal THF
# Postal Code 12161 assigned to Terminal THF
# Postal Code 12163 assigned to Terminal THF
# Postal Code 12165 assigned to Terminal THF
# Postal Code 12167 assigned to Terminal THF
# Postal Code 12169 assigned to Terminal THF
# Postal Code 12203 assigned to Terminal THF
# Postal Code 12205 assigned to Terminal THF
# Postal Code 12207 assigned to Terminal THF
# Postal Code 12209 assigned to Terminal THF
# Postal Code 12247 assigned to Terminal THF
# Postal Code 12249 assigned to Terminal THF
# Postal Code 12277 assigned to Terminal BER
# Postal Code 12279 assigned to Terminal THF
# Postal Code 12305 assigned to Terminal THF
# Postal Code 12307 assigned to Terminal THF
# Postal Code 12309 assigned to Terminal THF
# Postal Code 12347 assigned to Terminal THF
# Postal Code 12349 assigned to Terminal THF
# Postal Code 12351 assigned to Terminal THF
# Postal Code 12353 assigned to Terminal THF
# Postal Code 12355 assigned to Terminal THF
# Postal Code 12357 assigned to Terminal THF
# Postal Code 12359 assigned to Terminal THF
# Postal Code 12435 assigned to Terminal THF
# Postal Code 12437 assigned to Terminal THF
# Postal Code 12439 assigned to Terminal THF
# Postal Code 12459 assigned to Terminal THF
# Postal Code 12487 assigned to Terminal THF
# Postal Code 12489 assigned to Terminal THF
# Postal Code 12524 assigned to Terminal THF
# Postal Code 12526 assigned to Terminal THF
# Postal Code 12527 assigned to Terminal THF
# Postal Code 12529 assigned to Terminal THF
# Postal Code 12555 assigned to Terminal THF
# Postal Code 12557 assigned to Terminal THF
# Postal Code 12559 assigned to Terminal THF
# Postal Code 12587 assigned to Terminal THF
# Postal Code 12589 assigned to Terminal THF
# Postal Code 12619 assigned to Terminal THF
# Postal Code 12621 assigned to Terminal THF
# Postal Code 12623 assigned to Terminal THF
# Postal Code 12627 assigned to Terminal THF
# Postal Code 12629 assigned to Terminal THF
# Postal Code 12679 assigned to Terminal THF
# Postal Code 12681 assigned to Terminal BER
# Postal Code 12683 assigned to Terminal THF
# Postal Code 12685 assigned to Terminal THF
# Postal Code 12687 assigned to Terminal THF
# Postal Code 12689 assigned to Terminal THF
# Postal Code 13051 assigned to Terminal THF
# Postal Code 13053 assigned to Terminal THF
# Postal Code 13055 assigned to Terminal THF
# Postal Code 13057 assigned to Terminal THF
# Postal Code 13059 assigned to Terminal THF
# Postal Code 13086 assigned to Terminal THF
# Postal Code 13088 assigned to Terminal BER
# Postal Code 13089 assigned to Terminal THF
# Postal Code 13125 assigned to Terminal THF
# Postal Code 13127 assigned to Terminal THF
# Postal Code 13129 assigned to Terminal THF
# Postal Code 13156 assigned to Terminal BER
# Postal Code 13158 assigned to Terminal THF
# Postal Code 13159 assigned to Terminal THF
# Postal Code 13187 assigned to Terminal THF
# Postal Code 13189 assigned to Terminal THF
# Postal Code 13347 assigned to Terminal THF
# Postal Code 13349 assigned to Terminal THF
# Postal Code 13351 assigned to Terminal THF
# Postal Code 13353 assigned to Terminal BER
# Postal Code 13355 assigned to Terminal THF
# Postal Code 13357 assigned to Terminal THF
# Postal Code 13359 assigned to Terminal THF
# Postal Code 13403 assigned to Terminal BER
# Postal Code 13405 assigned to Terminal THF
# Postal Code 13407 assigned to Terminal BER
# Postal Code 13409 assigned to Terminal THF
# Postal Code 13435 assigned to Terminal THF
# Postal Code 13437 assigned to Terminal THF
# Postal Code 13439 assigned to Terminal BER
# Postal Code 13465 assigned to Terminal THF
# Postal Code 13467 assigned to Terminal THF
# Postal Code 13469 assigned to Terminal BER
# Postal Code 13503 assigned to Terminal THF
# Postal Code 13505 assigned to Terminal THF
# Postal Code 13507 assigned to Terminal BER
# Postal Code 13509 assigned to Terminal BER
# Postal Code 13581 assigned to Terminal BER
# Postal Code 13583 assigned to Terminal BER
# Postal Code 13585 assigned to Terminal BER
# Postal Code 13587 assigned to Terminal BER
# Postal Code 13589 assigned to Terminal BER
# Postal Code 13591 assigned to Terminal BER
# Postal Code 13593 assigned to Terminal BER
# Postal Code 13595 assigned to Terminal BER
# Postal Code 13597 assigned to Terminal BER
# Postal Code 13599 assigned to Terminal BER
# Postal Code 13627 assigned to Terminal BER
# Postal Code 13629 assigned to Terminal BER
# Postal Code 14050 assigned to Terminal THF
# Postal Code 14052 assigned to Terminal THF
# Postal Code 14053 assigned to Terminal THF
# Postal Code 14055 assigned to Terminal BER
# Postal Code 14057 assigned to Terminal THF
# Postal Code 14059 assigned to Terminal BER
# Postal Code 14089 assigned to Terminal BER
# Postal Code 14109 assigned to Terminal THF
# Postal Code 14129 assigned to Terminal THF
# Postal Code 14163 assigned to Terminal THF
# Postal Code 14165 assigned to Terminal THF
# Postal Code 14167 assigned to Terminal THF
# Postal Code 14169 assigned to Terminal THF
# Postal Code 14193 assigned to Terminal BER
# Postal Code 14195 assigned to Terminal THF
# Postal Code 14197 assigned to Terminal THF
# Postal Code 14199 assigned to Terminal THF
# Postal Code 14467 assigned to Terminal BER
# Postal Code 14469 assigned to Terminal BER
# Postal Code 14471 assigned to Terminal BER
# Postal Code 14473 assigned to Terminal BER
# Postal Code 14476 assigned to Terminal BER
# Postal Code 14478 assigned to Terminal BER
# Postal Code 14480 assigned to Terminal BER
# Postal Code 14482 assigned to Terminal BER
# Postal Code 14513 assigned to Terminal THF
# Postal Code 14532 assigned to Terminal BER
# Postal Code 14542 assigned to Terminal BER
# Postal Code 14547 assigned to Terminal BER
# Postal Code 14548 assigned to Terminal BER
# Postal Code 14550 assigned to Terminal BER
# Postal Code 14552 assigned to Terminal BER
# Postal Code 14554 assigned to Terminal THF
# Postal Code 14558 assigned to Terminal BER
# Postal Code 14612 assigned to Terminal BER
# Postal Code 14621 assigned to Terminal BER
# Postal Code 14624 assigned to Terminal BER
# Postal Code 14641 assigned to Terminal BER
# Postal Code 14656 assigned to Terminal BER
# Postal Code 14662 assigned to Terminal BER
# Postal Code 14669 assigned to Terminal BER
# Postal Code 14712 assigned to Terminal BER
# Postal Code 14715 assigned to Terminal BER
# Postal Code 14727 assigned to Terminal BER
# Postal Code 14728 assigned to Terminal BER
# Postal Code 14770 assigned to Terminal BER
# Postal Code 14772 assigned to Terminal BER
# Postal Code 14774 assigned to Terminal BER
# Postal Code 14776 assigned to Terminal BER
# Postal Code 14778 assigned to Terminal BER
# Postal Code 14789 assigned to Terminal CSO
# Postal Code 14793 assigned to Terminal CSO
# Postal Code 14797 assigned to Terminal BER
# Postal Code 14798 assigned to Terminal BER
# Postal Code 14806 assigned to Terminal BER
# Postal Code 14822 assigned to Terminal BER
# Postal Code 14823 assigned to Terminal BER
# Postal Code 14827 assigned to Terminal ZHZ
# Postal Code 14828 assigned to Terminal CSO
# Postal Code 14913 assigned to Terminal THF
# Postal Code 14929 assigned to Terminal BER
# Postal Code 14943 assigned to Terminal THF
# Postal Code 14947 assigned to Terminal THF
# Postal Code 14959 assigned to Terminal THF
# Postal Code 14974 assigned to Terminal BER
# Postal Code 14979 assigned to Terminal THF
# Postal Code 15230 assigned to Terminal CBU
# Postal Code 15232 assigned to Terminal CBU
# Postal Code 15234 assigned to Terminal THF
# Postal Code 15236 assigned to Terminal CBU
# Postal Code 15295 assigned to Terminal CBU
# Postal Code 15299 assigned to Terminal CBU
# Postal Code 15306 assigned to Terminal THF
# Postal Code 15320 assigned to Terminal THF
# Postal Code 15324 assigned to Terminal THF
# Postal Code 15326 assigned to Terminal CBU
# Postal Code 15328 assigned to Terminal CBU
# Postal Code 15344 assigned to Terminal THF
# Postal Code 15345 assigned to Terminal THF
# Postal Code 15366 assigned to Terminal BER
# Postal Code 15370 assigned to Terminal THF
# Postal Code 15374 assigned to Terminal THF
# Postal Code 15377 assigned to Terminal THF
# Postal Code 15378 assigned to Terminal THF
# Postal Code 15517 assigned to Terminal THF
# Postal Code 15518 assigned to Terminal THF
# Postal Code 15526 assigned to Terminal THF
# Postal Code 15528 assigned to Terminal THF
# Postal Code 15537 assigned to Terminal BER
# Postal Code 15562 assigned to Terminal THF
# Postal Code 15566 assigned to Terminal THF
# Postal Code 15569 assigned to Terminal THF
# Postal Code 15711 assigned to Terminal THF
# Postal Code 15712 assigned to Terminal THF
# Postal Code 15713 assigned to Terminal THF
# Postal Code 15732 assigned to Terminal THF
# Postal Code 15738 assigned to Terminal THF
# Postal Code 15741 assigned to Terminal THF
# Postal Code 15745 assigned to Terminal THF
# Postal Code 15746 assigned to Terminal THF
# Postal Code 15748 assigned to Terminal THF
# Postal Code 15749 assigned to Terminal THF
# Postal Code 15754 assigned to Terminal THF
# Postal Code 15755 assigned to Terminal THF
# Postal Code 15757 assigned to Terminal THF
# Postal Code 15806 assigned to Terminal THF
# Postal Code 15827 assigned to Terminal THF
# Postal Code 15831 assigned to Terminal THF
# Postal Code 15834 assigned to Terminal THF
# Postal Code 15837 assigned to Terminal THF
# Postal Code 15838 assigned to Terminal THF
# Postal Code 15848 assigned to Terminal CBU
# Postal Code 15859 assigned to Terminal THF
# Postal Code 15864 assigned to Terminal THF
# Postal Code 15868 assigned to Terminal CBU
# Postal Code 15890 assigned to Terminal CBU
# Postal Code 15898 assigned to Terminal CBU
# Postal Code 15907 assigned to Terminal CBU
# Postal Code 15910 assigned to Terminal CBU
# Postal Code 15913 assigned to Terminal CBU
# Postal Code 15926 assigned to Terminal CBU
# Postal Code 15936 assigned to Terminal THF
# Postal Code 15938 assigned to Terminal THF
# Postal Code 16225 assigned to Terminal THF
# Postal Code 16227 assigned to Terminal THF
# Postal Code 16230 assigned to Terminal THF
# Postal Code 16244 assigned to Terminal THF
# Postal Code 16247 assigned to Terminal THF
# Postal Code 16248 assigned to Terminal THF
# Postal Code 16259 assigned to Terminal THF
# Postal Code 16269 assigned to Terminal THF
# Postal Code 16278 assigned to Terminal THF
# Postal Code 16303 assigned to Terminal AQW
# Postal Code 16306 assigned to Terminal AQW
# Postal Code 16307 assigned to Terminal AQW
# Postal Code 16321 assigned to Terminal THF
# Postal Code 16341 assigned to Terminal THF
# Postal Code 16348 assigned to Terminal THF
# Postal Code 16356 assigned to Terminal BER
# Postal Code 16359 assigned to Terminal THF
# Postal Code 16515 assigned to Terminal BER
# Postal Code 16540 assigned to Terminal BER
# Postal Code 16547 assigned to Terminal BER
# Postal Code 16548 assigned to Terminal THF
# Postal Code 16552 assigned to Terminal THF
# Postal Code 16556 assigned to Terminal BER
# Postal Code 16559 assigned to Terminal THF
# Postal Code 16562 assigned to Terminal BER
# Postal Code 16567 assigned to Terminal THF
# Postal Code 16727 assigned to Terminal BER
# Postal Code 16761 assigned to Terminal BER
# Postal Code 16766 assigned to Terminal BER
# Postal Code 16767 assigned to Terminal BER
# Postal Code 16775 assigned to Terminal BER
# Postal Code 16792 assigned to Terminal BER
# Postal Code 16798 assigned to Terminal BER
# Postal Code 16816 assigned to Terminal BER
# Postal Code 16818 assigned to Terminal BER
# Postal Code 16827 assigned to Terminal BER
# Postal Code 16831 assigned to Terminal BER
# Postal Code 16833 assigned to Terminal BER
# Postal Code 16835 assigned to Terminal BER
# Postal Code 16837 assigned to Terminal PVM
# Postal Code 16845 assigned to Terminal BER
# Postal Code 16866 assigned to Terminal PVM
# Postal Code 16868 assigned to Terminal BER
# Postal Code 16909 assigned to Terminal PVM
# Postal Code 16928 assigned to Terminal PVM
# Postal Code 16945 assigned to Terminal PVM
# Postal Code 16949 assigned to Terminal PVM
# Postal Code 17033 assigned to Terminal AQW
# Postal Code 17034 assigned to Terminal AQW
# Postal Code 17036 assigned to Terminal AQW
# Postal Code 17039 assigned to Terminal AQW
# Postal Code 17087 assigned to Terminal AQW
# Postal Code 17089 assigned to Terminal AQW
# Postal Code 17091 assigned to Terminal AQW
# Postal Code 17094 assigned to Terminal AQW
# Postal Code 17098 assigned to Terminal AQW
# Postal Code 17099 assigned to Terminal AQW
# Postal Code 17109 assigned to Terminal AQW
# Postal Code 17111 assigned to Terminal AQW
# Postal Code 17121 assigned to Terminal AQW
# Postal Code 17126 assigned to Terminal AQW
# Postal Code 17129 assigned to Terminal AQW
# Postal Code 17139 assigned to Terminal AQW
# Postal Code 17153 assigned to Terminal AQW
# Postal Code 17154 assigned to Terminal AQW
# Postal Code 17159 assigned to Terminal AQW
# Postal Code 17166 assigned to Terminal AQW
# Postal Code 17168 assigned to Terminal AQW
# Postal Code 17179 assigned to Terminal AQW
# Postal Code 17192 assigned to Terminal AQW
# Postal Code 17194 assigned to Terminal PVM
# Postal Code 17207 assigned to Terminal PVM
# Postal Code 17209 assigned to Terminal PVM
# Postal Code 17213 assigned to Terminal PVM
# Postal Code 17214 assigned to Terminal PVM
# Postal Code 17217 assigned to Terminal AQW
# Postal Code 17219 assigned to Terminal AQW
# Postal Code 17235 assigned to Terminal AQW
# Postal Code 17237 assigned to Terminal AQW
# Postal Code 17248 assigned to Terminal PVM
# Postal Code 17252 assigned to Terminal AQW
# Postal Code 17255 assigned to Terminal AQW
# Postal Code 17258 assigned to Terminal AQW
# Postal Code 17268 assigned to Terminal BER
# Postal Code 17279 assigned to Terminal AQW
# Postal Code 17291 assigned to Terminal AQW
# Postal Code 17309 assigned to Terminal AQW
# Postal Code 17321 assigned to Terminal AQW
# Postal Code 17322 assigned to Terminal AQW
# Postal Code 17326 assigned to Terminal AQW
# Postal Code 17328 assigned to Terminal AQW
# Postal Code 17329 assigned to Terminal AQW
# Postal Code 17335 assigned to Terminal AQW
# Postal Code 17337 assigned to Terminal AQW
# Postal Code 17348 assigned to Terminal AQW
# Postal Code 17349 assigned to Terminal AQW
# Postal Code 17358 assigned to Terminal AQW
# Postal Code 17367 assigned to Terminal AQW
# Postal Code 17373 assigned to Terminal AQW
# Postal Code 17375 assigned to Terminal AQW
# Postal Code 17379 assigned to Terminal AQW
# Postal Code 17389 assigned to Terminal AQW
# Postal Code 17390 assigned to Terminal AQW
# Postal Code 17391 assigned to Terminal AQW
# Postal Code 17392 assigned to Terminal AQW
# Postal Code 17398 assigned to Terminal AQW
# Postal Code 17406 assigned to Terminal AQW
# Postal Code 17419 assigned to Terminal AQW
# Postal Code 17424 assigned to Terminal AQW
# Postal Code 17429 assigned to Terminal AQW
# Postal Code 17438 assigned to Terminal AQW
# Postal Code 17440 assigned to Terminal AQW
# Postal Code 17449 assigned to Terminal AQW
# Postal Code 17454 assigned to Terminal AQW
# Postal Code 17459 assigned to Terminal AQW
# Postal Code 17489 assigned to Terminal AQW
# Postal Code 17491 assigned to Terminal AQW
# Postal Code 17493 assigned to Terminal AQW
# Postal Code 17495 assigned to Terminal AQW
# Postal Code 17498 assigned to Terminal AQW
# Postal Code 17506 assigned to Terminal AQW
# Postal Code 17509 assigned to Terminal AQW
# Postal Code 18055 assigned to Terminal PVM
# Postal Code 18057 assigned to Terminal PVM
# Postal Code 18059 assigned to Terminal PVM
# Postal Code 18069 assigned to Terminal PVM
# Postal Code 18106 assigned to Terminal PVM
# Postal Code 18107 assigned to Terminal PVM
# Postal Code 18109 assigned to Terminal PVM
# Postal Code 18119 assigned to Terminal PVM
# Postal Code 18146 assigned to Terminal PVM
# Postal Code 18147 assigned to Terminal PVM
# Postal Code 18181 assigned to Terminal PVM
# Postal Code 18182 assigned to Terminal PVM
# Postal Code 18184 assigned to Terminal PVM
# Postal Code 18190 assigned to Terminal PVM
# Postal Code 18195 assigned to Terminal AQW
# Postal Code 18196 assigned to Terminal PVM
# Postal Code 18198 assigned to Terminal PVM
# Postal Code 18209 assigned to Terminal PVM
# Postal Code 18211 assigned to Terminal PVM
# Postal Code 18225 assigned to Terminal PVM
# Postal Code 18230 assigned to Terminal PVM
# Postal Code 18233 assigned to Terminal PVM
# Postal Code 18236 assigned to Terminal PVM
# Postal Code 18239 assigned to Terminal PVM
# Postal Code 18246 assigned to Terminal PVM
# Postal Code 18249 assigned to Terminal PVM
# Postal Code 18258 assigned to Terminal PVM
# Postal Code 18273 assigned to Terminal PVM
# Postal Code 18276 assigned to Terminal PVM
# Postal Code 18279 assigned to Terminal AQW
# Postal Code 18292 assigned to Terminal PVM
# Postal Code 18299 assigned to Terminal AQW
# Postal Code 18311 assigned to Terminal AQW
# Postal Code 18314 assigned to Terminal AQW
# Postal Code 18317 assigned to Terminal AQW
# ...
# Postal Code 96328 assigned to Terminal OKZ
# Postal Code 96332 assigned to Terminal OKZ
# Postal Code 96337 assigned to Terminal OKZ
# Postal Code 96342 assigned to Terminal OKZ
# Postal Code 96346 assigned to Terminal OKZ
# Postal Code 96349 assigned to Terminal OKZ
# Postal Code 96352 assigned to Terminal OKZ
# Postal Code 96355 assigned to Terminal OKZ
# Postal Code 96358 assigned to Terminal OKZ
# Postal Code 96361 assigned to Terminal OKZ
# Postal Code 96364 assigned to Terminal OKZ
# Postal Code 96365 assigned to Terminal OKZ
# Postal Code 96367 assigned to Terminal OKZ
# Postal Code 96369 assigned to Terminal OKZ
# Postal Code 96450 assigned to Terminal GOH
# Postal Code 96465 assigned to Terminal GOH
# Postal Code 96472 assigned to Terminal GOH
# Postal Code 96476 assigned to Terminal GOH
# Postal Code 96479 assigned to Terminal GOH
# Postal Code 96482 assigned to Terminal GOH
# Postal Code 96484 assigned to Terminal GOH
# Postal Code 96486 assigned to Terminal GOH
# Postal Code 96487 assigned to Terminal GOH
# Postal Code 96489 assigned to Terminal GOH
# Postal Code 96515 assigned to Terminal OKZ
# Postal Code 96523 assigned to Terminal OKZ
# Postal Code 96524 assigned to Terminal OKZ
# Postal Code 96528 assigned to Terminal GOH
# Postal Code 97070 assigned to Terminal GOH
# Postal Code 97072 assigned to Terminal GOH
# Postal Code 97074 assigned to Terminal GOH
# Postal Code 97076 assigned to Terminal GOH
# Postal Code 97078 assigned to Terminal GOH
# Postal Code 97080 assigned to Terminal GOH
# Postal Code 97082 assigned to Terminal GOH
# Postal Code 97084 assigned to Terminal GOH
# Postal Code 97199 assigned to Terminal GOH
# Postal Code 97204 assigned to Terminal GOH
# Postal Code 97209 assigned to Terminal GOH
# Postal Code 97215 assigned to Terminal NUE
# Postal Code 97218 assigned to Terminal GOH
# Postal Code 97222 assigned to Terminal GOH
# Postal Code 97225 assigned to Terminal GOH
# Postal Code 97228 assigned to Terminal GOH
# Postal Code 97230 assigned to Terminal GOH
# Postal Code 97232 assigned to Terminal GOH
# Postal Code 97234 assigned to Terminal GOH
# Postal Code 97236 assigned to Terminal GOH
# Postal Code 97237 assigned to Terminal GOH
# Postal Code 97239 assigned to Terminal ZNJ
# Postal Code 97241 assigned to Terminal GOH
# Postal Code 97243 assigned to Terminal ZNJ
# Postal Code 97244 assigned to Terminal ZNJ
# Postal Code 97246 assigned to Terminal GOH
# Postal Code 97247 assigned to Terminal GOH
# Postal Code 97249 assigned to Terminal GOH
# Postal Code 97250 assigned to Terminal GOH
# Postal Code 97252 assigned to Terminal GOH
# Postal Code 97253 assigned to Terminal GOH
# Postal Code 97255 assigned to Terminal ZNJ
# Postal Code 97256 assigned to Terminal GOH
# Postal Code 97258 assigned to Terminal GOH
# Postal Code 97259 assigned to Terminal GOH
# Postal Code 97261 assigned to Terminal GOH
# Postal Code 97262 assigned to Terminal GOH
# Postal Code 97264 assigned to Terminal GOH
# Postal Code 97265 assigned to Terminal GOH
# Postal Code 97267 assigned to Terminal GOH
# Postal Code 97268 assigned to Terminal GOH
# Postal Code 97270 assigned to Terminal GOH
# Postal Code 97271 assigned to Terminal GOH
# Postal Code 97273 assigned to Terminal GOH
# Postal Code 97274 assigned to Terminal GOH
# Postal Code 97276 assigned to Terminal GOH
# Postal Code 97277 assigned to Terminal GOH
# Postal Code 97279 assigned to Terminal GOH
# Postal Code 97280 assigned to Terminal GOH
# Postal Code 97282 assigned to Terminal GOH
# Postal Code 97283 assigned to Terminal ZNJ
# Postal Code 97285 assigned to Terminal ZNJ
# Postal Code 97286 assigned to Terminal GOH
# Postal Code 97288 assigned to Terminal GOH
# Postal Code 97289 assigned to Terminal GOH
# Postal Code 97291 assigned to Terminal GOH
# Postal Code 97292 assigned to Terminal GOH
# Postal Code 97294 assigned to Terminal GOH
# Postal Code 97295 assigned to Terminal GOH
# Postal Code 97297 assigned to Terminal GOH
# Postal Code 97299 assigned to Terminal GOH
# Postal Code 97318 assigned to Terminal GOH
# Postal Code 97320 assigned to Terminal GOH
# Postal Code 97332 assigned to Terminal GOH
# Postal Code 97334 assigned to Terminal GOH
# Postal Code 97337 assigned to Terminal GOH
# Postal Code 97340 assigned to Terminal GOH
# Postal Code 97342 assigned to Terminal GOH
# Postal Code 97346 assigned to Terminal GOH
# Postal Code 97348 assigned to Terminal GOH
# Postal Code 97350 assigned to Terminal GOH
# Postal Code 97353 assigned to Terminal GOH
# Postal Code 97355 assigned to Terminal GOH
# Postal Code 97357 assigned to Terminal GOH
# Postal Code 97359 assigned to Terminal GOH
# Postal Code 97421 assigned to Terminal GOH
# Postal Code 97422 assigned to Terminal GOH
# Postal Code 97424 assigned to Terminal GOH
# Postal Code 97437 assigned to Terminal GOH
# Postal Code 97440 assigned to Terminal GOH
# Postal Code 97447 assigned to Terminal GOH
# Postal Code 97450 assigned to Terminal GOH
# Postal Code 97453 assigned to Terminal GOH
# Postal Code 97456 assigned to Terminal GOH
# Postal Code 97461 assigned to Terminal GOH
# Postal Code 97464 assigned to Terminal GOH
# Postal Code 97469 assigned to Terminal GOH
# Postal Code 97475 assigned to Terminal GOH
# Postal Code 97478 assigned to Terminal GOH
# Postal Code 97483 assigned to Terminal GOH
# Postal Code 97486 assigned to Terminal GOH
# Postal Code 97488 assigned to Terminal GOH
# Postal Code 97490 assigned to Terminal GOH
# Postal Code 97491 assigned to Terminal GOH
# Postal Code 97493 assigned to Terminal GOH
# Postal Code 97494 assigned to Terminal GOH
# Postal Code 97496 assigned to Terminal GOH
# Postal Code 97497 assigned to Terminal GOH
# Postal Code 97499 assigned to Terminal GOH
# Postal Code 97500 assigned to Terminal GOH
# Postal Code 97502 assigned to Terminal GOH
# Postal Code 97503 assigned to Terminal GOH
# Postal Code 97505 assigned to Terminal GOH
# Postal Code 97506 assigned to Terminal GOH
# Postal Code 97508 assigned to Terminal GOH
# Postal Code 97509 assigned to Terminal GOH
# Postal Code 97511 assigned to Terminal GOH
# Postal Code 97513 assigned to Terminal GOH
# Postal Code 97514 assigned to Terminal GOH
# Postal Code 97516 assigned to Terminal GOH
# Postal Code 97517 assigned to Terminal GOH
# Postal Code 97519 assigned to Terminal GOH
# Postal Code 97520 assigned to Terminal GOH
# Postal Code 97522 assigned to Terminal GOH
# Postal Code 97523 assigned to Terminal GOH
# Postal Code 97525 assigned to Terminal GOH
# Postal Code 97526 assigned to Terminal GOH
# Postal Code 97528 assigned to Terminal GOH
# Postal Code 97529 assigned to Terminal GOH
# Postal Code 97531 assigned to Terminal GOH
# Postal Code 97532 assigned to Terminal GOH
# Postal Code 97534 assigned to Terminal GOH
# Postal Code 97535 assigned to Terminal GOH
# Postal Code 97537 assigned to Terminal GOH
# Postal Code 97539 assigned to Terminal GOH
# Postal Code 97616 assigned to Terminal GOH
# Postal Code 97618 assigned to Terminal GOH
# Postal Code 97631 assigned to Terminal GOH
# Postal Code 97633 assigned to Terminal GOH
# Postal Code 97638 assigned to Terminal GOH
# Postal Code 97640 assigned to Terminal GOH
# Postal Code 97645 assigned to Terminal GOH
# Postal Code 97647 assigned to Terminal GOH
# Postal Code 97650 assigned to Terminal GOH
# Postal Code 97653 assigned to Terminal GOH
# Postal Code 97654 assigned to Terminal GOH
# Postal Code 97656 assigned to Terminal GOH
# Postal Code 97657 assigned to Terminal GOH
# Postal Code 97659 assigned to Terminal GOH
# Postal Code 97688 assigned to Terminal GOH
# Postal Code 97702 assigned to Terminal GOH
# Postal Code 97705 assigned to Terminal GOH
# Postal Code 97708 assigned to Terminal GOH
# Postal Code 97711 assigned to Terminal GOH
# Postal Code 97714 assigned to Terminal GOH
# Postal Code 97717 assigned to Terminal GOH
# Postal Code 97720 assigned to Terminal GOH
# Postal Code 97723 assigned to Terminal GOH
# Postal Code 97724 assigned to Terminal GOH
# Postal Code 97725 assigned to Terminal GOH
# Postal Code 97727 assigned to Terminal GOH
# Postal Code 97729 assigned to Terminal GOH
# Postal Code 97737 assigned to Terminal GOH
# Postal Code 97753 assigned to Terminal GOH
# Postal Code 97762 assigned to Terminal GOH
# Postal Code 97769 assigned to Terminal GOH
# Postal Code 97772 assigned to Terminal GOH
# Postal Code 97773 assigned to Terminal FRA
# Postal Code 97775 assigned to Terminal FRA
# Postal Code 97776 assigned to Terminal GOH
# Postal Code 97778 assigned to Terminal FRA
# Postal Code 97779 assigned to Terminal GOH
# Postal Code 97780 assigned to Terminal GOH
# Postal Code 97782 assigned to Terminal GOH
# Postal Code 97783 assigned to Terminal GOH
# Postal Code 97785 assigned to Terminal FRA
# Postal Code 97786 assigned to Terminal GOH
# Postal Code 97788 assigned to Terminal GOH
# Postal Code 97789 assigned to Terminal GOH
# Postal Code 97791 assigned to Terminal FRA
# Postal Code 97792 assigned to Terminal GOH
# Postal Code 97794 assigned to Terminal GOH
# Postal Code 97795 assigned to Terminal GOH
# Postal Code 97797 assigned to Terminal GOH
# Postal Code 97799 assigned to Terminal FRA
# Postal Code 97816 assigned to Terminal FRA
# Postal Code 97828 assigned to Terminal GOH
# Postal Code 97833 assigned to Terminal FRA
# Postal Code 97834 assigned to Terminal GOH
# Postal Code 97836 assigned to Terminal FRA
# Postal Code 97837 assigned to Terminal GOH
# Postal Code 97839 assigned to Terminal FRA
# Postal Code 97840 assigned to Terminal GOH
# Postal Code 97842 assigned to Terminal GOH
# Postal Code 97843 assigned to Terminal FRA
# Postal Code 97845 assigned to Terminal GOH
# Postal Code 97846 assigned to Terminal FRA
# Postal Code 97848 assigned to Terminal FRA
# Postal Code 97849 assigned to Terminal GOH
# Postal Code 97851 assigned to Terminal GOH
# Postal Code 97852 assigned to Terminal FRA
# Postal Code 97854 assigned to Terminal GOH
# Postal Code 97855 assigned to Terminal GOH
# Postal Code 97857 assigned to Terminal GOH
# Postal Code 97859 assigned to Terminal FRA
# Postal Code 97877 assigned to Terminal ZNJ
# Postal Code 97892 assigned to Terminal FRA
# Postal Code 97896 assigned to Terminal ZNJ
# Postal Code 97900 assigned to Terminal ZNJ
# Postal Code 97901 assigned to Terminal FRA
# Postal Code 97903 assigned to Terminal FRA
# Postal Code 97904 assigned to Terminal FRA
# Postal Code 97906 assigned to Terminal FRA
# Postal Code 97907 assigned to Terminal FRA
# Postal Code 97909 assigned to Terminal FRA
# Postal Code 97922 assigned to Terminal ZNJ
# Postal Code 97941 assigned to Terminal ZNJ
# Postal Code 97944 assigned to Terminal ZNJ
# Postal Code 97947 assigned to Terminal ZNJ
# Postal Code 97950 assigned to Terminal GOH
# Postal Code 97953 assigned to Terminal ZNJ
# Postal Code 97956 assigned to Terminal ZNJ
# Postal Code 97957 assigned to Terminal GOH
# Postal Code 97959 assigned to Terminal ZNJ
# Postal Code 97980 assigned to Terminal ZNJ
# Postal Code 97990 assigned to Terminal ZNJ
# Postal Code 97993 assigned to Terminal ZNJ
# Postal Code 97996 assigned to Terminal ZNJ
# Postal Code 97999 assigned to Terminal ZNJ
# Postal Code 98527 assigned to Terminal ERF
# Postal Code 98528 assigned to Terminal ERF
# Postal Code 98529 assigned to Terminal ERF
# Postal Code 98530 assigned to Terminal ERF
# Postal Code 98544 assigned to Terminal ERF
# Postal Code 98547 assigned to Terminal ERF
# Postal Code 98553 assigned to Terminal ERF
# Postal Code 98554 assigned to Terminal ERF
# Postal Code 98559 assigned to Terminal ERF
# Postal Code 98574 assigned to Terminal ERF
# Postal Code 98587 assigned to Terminal ERF
# Postal Code 98590 assigned to Terminal ERF
# Postal Code 98593 assigned to Terminal ERF
# Postal Code 98596 assigned to Terminal ERF
# Postal Code 98597 assigned to Terminal ERF
# Postal Code 98617 assigned to Terminal GOH
# Postal Code 98630 assigned to Terminal GOH
# Postal Code 98631 assigned to Terminal GOH
# Postal Code 98634 assigned to Terminal ERF
# Postal Code 98639 assigned to Terminal GOH
# Postal Code 98646 assigned to Terminal GOH
# Postal Code 98660 assigned to Terminal GOH
# Postal Code 98663 assigned to Terminal GOH
# Postal Code 98666 assigned to Terminal ERF
# Postal Code 98667 assigned to Terminal GOH
# Postal Code 98669 assigned to Terminal GOH
# Postal Code 98673 assigned to Terminal GOH
# Postal Code 98678 assigned to Terminal GOH
# Postal Code 98693 assigned to Terminal ERF
# Postal Code 98701 assigned to Terminal ERF
# Postal Code 98704 assigned to Terminal ERF
# Postal Code 98708 assigned to Terminal ERF
# Postal Code 98711 assigned to Terminal ERF
# Postal Code 98714 assigned to Terminal ERF
# Postal Code 98716 assigned to Terminal ERF
# Postal Code 98724 assigned to Terminal ERF
# Postal Code 98739 assigned to Terminal ERF
# Postal Code 98743 assigned to Terminal OKZ
# Postal Code 98744 assigned to Terminal ERF
# Postal Code 98746 assigned to Terminal ERF
# Postal Code 99084 assigned to Terminal ERF
# Postal Code 99085 assigned to Terminal ERF
# Postal Code 99086 assigned to Terminal ERF
# Postal Code 99087 assigned to Terminal ERF
# Postal Code 99089 assigned to Terminal ERF
# Postal Code 99090 assigned to Terminal ERF
# Postal Code 99091 assigned to Terminal ERF
# Postal Code 99092 assigned to Terminal ERF
# Postal Code 99094 assigned to Terminal ERF
# Postal Code 99095 assigned to Terminal ERF
# Postal Code 99096 assigned to Terminal ERF
# Postal Code 99097 assigned to Terminal ERF
# Postal Code 99098 assigned to Terminal ERF
# Postal Code 99099 assigned to Terminal ERF
# Postal Code 99100 assigned to Terminal ERF
# Postal Code 99102 assigned to Terminal ERF
# Postal Code 99189 assigned to Terminal ERF
# Postal Code 99192 assigned to Terminal ERF
# Postal Code 99195 assigned to Terminal ERF
# Postal Code 99198 assigned to Terminal ERF
# Postal Code 99310 assigned to Terminal ERF
# Postal Code 99326 assigned to Terminal ERF
# Postal Code 99330 assigned to Terminal ERF
# Postal Code 99334 assigned to Terminal ERF
# Postal Code 99338 assigned to Terminal ERF
# Postal Code 99423 assigned to Terminal ERF
# Postal Code 99425 assigned to Terminal ERF
# Postal Code 99427 assigned to Terminal ERF
# Postal Code 99428 assigned to Terminal ERF
# Postal Code 99438 assigned to Terminal ERF
# Postal Code 99439 assigned to Terminal ERF
# Postal Code 99441 assigned to Terminal ERF
# Postal Code 99444 assigned to Terminal ERF
# Postal Code 99448 assigned to Terminal ERF
# Postal Code 99510 assigned to Terminal ERF
# Postal Code 99518 assigned to Terminal ERF
# Postal Code 99610 assigned to Terminal ERF
# Postal Code 99625 assigned to Terminal ERF
# Postal Code 99628 assigned to Terminal ERF
# Postal Code 99631 assigned to Terminal ERF
# Postal Code 99634 assigned to Terminal ERF
# Postal Code 99636 assigned to Terminal ERF
# Postal Code 99638 assigned to Terminal ERF
# Postal Code 99706 assigned to Terminal ERF
# Postal Code 99707 assigned to Terminal ERF
# Postal Code 99713 assigned to Terminal ERF
# Postal Code 99718 assigned to Terminal ERF
# Postal Code 99734 assigned to Terminal ERF
# Postal Code 99735 assigned to Terminal ERF
# Postal Code 99752 assigned to Terminal ERF
# Postal Code 99755 assigned to Terminal ERF
# Postal Code 99759 assigned to Terminal ERF
# Postal Code 99762 assigned to Terminal ERF
# Postal Code 99765 assigned to Terminal ERF
# Postal Code 99768 assigned to Terminal ERF
# Postal Code 99817 assigned to Terminal ERF
# Postal Code 99819 assigned to Terminal KSF
# Postal Code 99820 assigned to Terminal ERF
# Postal Code 99826 assigned to Terminal KSF
# Postal Code 99830 assigned to Terminal KSF
# Postal Code 99831 assigned to Terminal KSF
# Postal Code 99834 assigned to Terminal KSF
# Postal Code 99837 assigned to Terminal KSF
# Postal Code 99842 assigned to Terminal ERF
# Postal Code 99846 assigned to Terminal ERF
# Postal Code 99848 assigned to Terminal ERF
# Postal Code 99867 assigned to Terminal ERF
# Postal Code 99869 assigned to Terminal ERF
# Postal Code 99880 assigned to Terminal ERF
# Postal Code 99885 assigned to Terminal ERF
# Postal Code 99887 assigned to Terminal ERF
# Postal Code 99891 assigned to Terminal ERF
# Postal Code 99894 assigned to Terminal ERF
# Postal Code 99897 assigned to Terminal ERF
# Postal Code 99947 assigned to Terminal ERF
# Postal Code 99955 assigned to Terminal ERF
# Postal Code 99958 assigned to Terminal ERF
# Postal Code 99974 assigned to Terminal ERF
# Postal Code 99976 assigned to Terminal ERF
# Postal Code 99986 assigned to Terminal ERF
# Postal Code 99988 assigned to Terminal KSF
# Postal Code 99991 assigned to Terminal ERF
# Postal Code 99994 assigned to Terminal ERF
# Postal Code 99996 assigned to Terminal ERF
# Postal Code 99998 assigned to Terminal ERF
